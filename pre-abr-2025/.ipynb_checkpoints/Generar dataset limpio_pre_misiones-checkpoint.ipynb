# %% [markdown]
# # Generar dataset limpio
#
# Qué hay que chequear:
# * No son de entrenamiento
# * Los tiempo de respuesta > a 7000 -> correct = 0
# * No hay attempts < a 4
#
# ## Info sobre las pruebas
#
# La cantidad de ejercicios es _sin contar entrenamiento_.
#
# * Vocabulario (2022): 45 ejercicios - 34 SIN LAS FÁCILES
# * Conciencia fonológica (2024): 20 ejercicios
# * Sistema de escritura (2024): 10 ejercicios
#
# accuracy_totales es count_correctas / count_max . Es decir sobre los valores que están arriba para cada prueba.
# accuracy es el mean de las respuestas. --> (correct, mean)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("df_misiones.csv")
df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df=pd.read_csv("df_misiones.csv")
#       2 df.shape
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_misiones.csv'

# %% [markdown]
# ## Columnas:

# %%
column_map = {
    "Código de anonimización": "codigo",
    "Fecha de nacimiento": "fecha_nac",
    "Género": "genero",
    "Jardín": "jardin",
    "Sala": "sala",
    "Supervisión": "supervision",
    "Ocupación de los padres": "ocup_padres",
    "Comentarios": "comentarios",
    "ID_voc":"esp2022",
    "ID_conc_fono":"concienciaFonologica2024",
    "ID_sist_escrit":"sistemaEscritura2024"
}

# Renombrar columnas en merged_df
df_entrerios.rename(columns=column_map, inplace=True)

# %%
filas_vacias_jardin = df_entrerios[df_entrerios['jardin'].astype(str).str.strip().eq('') | df_entrerios['jardin'].isna()]
# filas_vacias_jardin

# %%
df_entrerios = df_entrerios.drop(filas_vacias_jardin.index)

# %%
cond1 = (df_entrerios["jardin"] == "ESCUELA PRIMaría N 8") & (df_entrerios["supervision"].str.contains("GUALEGUAY ZONA XI - Mónica Gimenez"))
df_entrerios.loc[cond1, "jardin"] = "Esc Prim N 8 (Gualeguay)"

cond2 = (df_entrerios["jardin"] == "ESC EDU PRIM N 8") & (df_entrerios["supervision"].str.contains("URUGUAY ZONA IV - Silvina Daniela Suarez"))
df_entrerios.loc[cond2, "jardin"] = "Esc Prim N 8 (Uruguay)"

cond3 = (df_entrerios["jardin"] == "ESC EDU PRIM N 8") & (df_entrerios["supervision"].str.contains("ISLAS ZONA XIV -Jacinta Maciel"))
df_entrerios.loc[cond3, "jardin"] = "Esc Prim N 8 (Ibicuy)"

cond4 = (df_entrerios["jardin"] == "ESC EDU PRIM N 8") & (df_entrerios["supervision"].str.contains("FEDERAL ZONA VI - Betina Inés Ava"))
df_entrerios.loc[cond4, "jardin"] = "Esc Prim N 8 (Federal)"

cond5 = (df_entrerios["jardin"] == "Esc Edu PrriMaría N 8") & (df_entrerios["supervision"].str.contains("DIAMANTE ZONA XII - Miriam Elena Retegui"))
df_entrerios.loc[cond5, "jardin"] = "Esc Prim N 8 (Diamante)"

# %%
jardines_df = pd.DataFrame(df_entrerios["jardin"].unique(), columns=["jardin"])
jardines_df.sort_values(by="jardin", inplace=True)

# Eliminar espacios
df_entrerios['jardin'] = df_entrerios['jardin'].str.strip()

# Convertir a minúsculas
df_entrerios['jardin'] = df_entrerios['jardin'].str.lower()

# Eliminar puntos
df_entrerios['jardin'] = df_entrerios['jardin'].str.replace(r'\.', '', regex=True)

# mayúscula la primera letra
df_entrerios['jardin'] = df_entrerios['jardin'].str.title()

jardines_df = pd.DataFrame(df_entrerios["jardin"].unique(), columns=["jardin"])
jardines_df.sort_values(by="jardin", inplace=True)

# # # Reemplazo
# # df_entrerios['jardin'] = df_entrerios['jardin'].replace(jardin_unificado)
# jardines_df.to_csv("jardines_df.csv")
jardines_df.shape
# Out:
# (117, 1)

# %%
# Cargar el archivo CSV que contiene el diccionario de cambios.
dicc_df = pd.read_csv("jardines_dicc.csv")

# Convertir el DataFrame de diccionario en un diccionario de Python.
diccionario_cambios = dict(zip(dicc_df['jardin'], dicc_df['new']))

# Aplicar los cambios en la columna 'jardin' del DataFrame usando reemplazo por expresión regular.
df_entrerios['jardin'] = df_entrerios['jardin'].replace(diccionario_cambios, regex=True)

# %%
# Modificar los valores de la columna "supervision" en función de la columna "jardin"
df_entrerios.loc[df_entrerios["jardin"] == "Ueni N 23", "supervision"] = "GUALEGUAY ZONA XI - Mónica Gimenez"
df_entrerios.loc[df_entrerios["jardin"] == "Esc Priv Prim N 22", "supervision"] = "FEDERAL ZONA VI - Betina Inés Ava"
df_entrerios.loc[df_entrerios["jardin"] == "Esc Priv Prim N 86", "supervision"] = "NOGOYÁ ZONA VIII - Nancy Kergaravat"

# %%
# Reviso que los valores de supervisoras estén unificados

supervisoras_df = pd.DataFrame(df_entrerios["supervision"].unique(), columns=["supervision"])
supervisoras_df.sort_values(by="supervision", inplace=True)
supervisoras_df
# Out:
#                                         supervision
# 7                  COLÓN ZONA XIII - Laura Apendino
# 6         CONCORDIA ZONA V - Cecilia Julieta Garcia
# 10        ConCORDIA ZONA V - Cecilia Julieta Garcia
# 20         DIAMANTE ZONA XII - Miriam Elena Retegui
# 12          FEDERACIÓN ZONA XV - Clarisa Mabel Mela
# 5                 FEDERAL ZONA VI - Betina Inés Ava
# 1   FELICIANO ZONA XVIII - María Jorgelina Paniagua
# 0                               FELICIANO ZONAXVIII
# 9                                   GESTION PRIVADA
# 14               GUALEGUAY ZONA XI - Mónica Gimenez
# 32    GUALEGUAYCHÚ ZONA IX - Sandra Maricel Peltzer
# 25                   ISLAS ZONA XIV -Jacinta Maciel
# 3            LA PAZ ZONA VII - Norma Grisel Culpian
# 22              NOGOYÁ ZONA VIII - Nancy Kergaravat
# 21             PARANA  ZONA II - Claudio G. Lomagno
# 15               PARANA ZONA I - Ana Delia González
# 13                       PARANA ZONA XX - Mabel Sea
# 16               PARANA ZONA XXI - Viviana Martínez
# 8            SAN SALVADOR ZONA XIX - Sandra Urbarni
# 23                                    SUP.ZONA XXII
# 2                            Santa Cruz Ruben Dario
# 26                   TALA ZONA XVII - Mónica Londra
# 27         URUGUAY ZONA IV - Silvina Daniela Suarez
# 30         URuGUAY ZONA IV - Silvina Daniela Suarez
# 29         UruGUAY ZONA IV - Silvina Daniela Suarez
# 24         VICTORIA ZONA III - Natalia Andrea Rizzo
# 4       VILLAGUAY ZONA X - Lorena Soraya E. Vergara
# 11                                        ZONA XXII
# 17                                          Zona II
# 18                                         Zona II
# 19                                        Zona XXI
# 31               gUALEGUAY ZONA XI - Mónica Gimenez
# 28         uruGUAY ZONA IV - Silvina Daniela Suarez

# %%
# Eliminar espacios
df_entrerios['supervision'] = df_entrerios['supervision'].str.strip()

# Convertir a minúsculas
df_entrerios['supervision'] = df_entrerios['supervision'].str.lower()

# Eliminar puntos
df_entrerios['supervision'] = df_entrerios['supervision'].str.replace(r'\,', '', regex=True)

# mayúscula la primera letra
df_entrerios['supervision'] = df_entrerios['supervision'].str.title()

nombre_unificado = {
    'Zona Xxii': 'Diamante Zona Xii - Miriam Elena Retegui',
     'Sup.Zona Xxii': 'Diamante Zona Xii - Miriam Elena Retegui',
    'Paraná Zona I: Ana Delia González. Inicial.1.P...': 'Parana Zona I - Ana Delia González',
    'Feliciano Zonaxviii': 'Feliciano Zona Xviii - María Jorgelina Paniagua',
    'Zona Ii': 'Parana  Zona Ii - Claudio G. Lomagno',
    'Zona Xxi': ' Parana Zona Xxi - Viviana Martínez',  
}

# Reemplazo
df_entrerios['supervision'] = df_entrerios['supervision'].replace(nombre_unificado)

supervision_df = pd.DataFrame(df_entrerios["supervision"].unique(), columns=["supervision"])
supervision_df.sort_values(by="supervision", inplace=True)
print(supervision_df)
# Out:
#                                         supervision
# 16               Parana Zona Xxi - Viviana Martínez
# 6                  Colón Zona Xiii - Laura Apendino
# 5         Concordia Zona V - Cecilia Julieta Garcia
# 9          Diamante Zona Xii - Miriam Elena Retegui
# 10          Federación Zona Xv - Clarisa Mabel Mela
# 4                 Federal Zona Vi - Betina Inés Ava
# 0   Feliciano Zona Xviii - María Jorgelina Paniagua
# 8                                   Gestion Privada
# 12               Gualeguay Zona Xi - Mónica Gimenez
# 22    Gualeguaychú Zona Ix - Sandra Maricel Peltzer
# 19                   Islas Zona Xiv -Jacinta Maciel
# 2            La Paz Zona Vii - Norma Grisel Culpian
# 17              Nogoyá Zona Viii - Nancy Kergaravat
# 15             Parana  Zona Ii - Claudio G. Lomagno
# 13               Parana Zona I - Ana Delia González
# 11                       Parana Zona Xx - Mabel Sea
# 14               Parana Zona Xxi - Viviana Martínez
# 7            San Salvador Zona Xix - Sandra Urbarni
# 1                            Santa Cruz Ruben Dario
# 20                   Tala Zona Xvii - Mónica Londra
# 21         Uruguay Zona Iv - Silvina Daniela Suarez
# 18         Victoria Zona Iii - Natalia Andrea Rizzo
# 3       Villaguay Zona X - Lorena Soraya E. Vergara

# %%
# set(nombre_unificado.keys()) - set(df_entrerios['supervision'].unique())

# %%
supervision_df = df_entrerios["supervision"].value_counts().reset_index()

# %%
df_entrerios[df_entrerios["supervision"].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, codigo, fecha_nac, genero, jardin, sala, version_voc, version_conc_fono, version_sist_escrit, supervision, localidad, ocup_padres, comentarios, esp2022, concienciaFonologica2024, sistemaEscritura2024]
# Index: []

# %%
# Eliminar espacios
df_entrerios['localidad'] = df_entrerios['localidad'].str.strip()

# Convertir a minúsculas
df_entrerios['localidad'] = df_entrerios['localidad'].str.lower()

# Eliminar puntos
df_entrerios['localidad'] = df_entrerios['localidad'].str.replace(r'\.', '', regex=True)

# mayúscula la primera letra
df_entrerios['localidad'] = df_entrerios['localidad'].str.title()

localidad_df = pd.DataFrame(df_entrerios["localidad"].unique(), columns=["localidad"])
localidad_df.sort_values(by="localidad", inplace=True)

# %%
nombre_unificado_localidad = {
    'Gualeguachú': 'Gualeguaychú',
    'Parana': 'Paraná',
    'Rdel Tala': 'Rosario Del Tala',  
#     '': ''
}

df_entrerios['localidad'] = df_entrerios['localidad'].replace(nombre_unificado_localidad)
df_entrerios["localidad"].unique()
# Out:
# array(['San José De Feliciano', 'Comuna San Victor Distrito Manantiales',
#        'Santa Elena', 'La Paz', 'Paraje Tacuara', 'Villaguay',
#        'Paso De La Laguna', 'Ingeniero Miguel Sajaroff', 'Federal',
#        'Paraje Yacaré', 'Concordia', 'Puerto Yerua', nan,
#        'Estación Yerua', 'Colón', 'San Jose', 'San Salvador',
#        'Colónia La Armonía', 'Colónia Santa Elena', 'Arroyo Baru',
#        'Chajari', 'Federación', 'Paraje Guayaquil', 'Hernandarias',
#        'Gualeguay', 'Puerto Víboras', 'Villa Urquiza', 'Hasemkamp',
#        'Crespo', 'Paraná', 'Las Cuevas', 'Pueblo Nuevo Gral Alvear',
#        'Colónia Ensayo', 'General Ramírez', 'Diamante', 'La Verbena',
#        'Nogoyá', 'Crucecitas 3Ra', 'Colónia Avellaneda', 'Victoria',
#        'Hernández', 'Aranguren', 'Rincón De Nogoyá', 'Strobel', 'Islas',
#        'Paraje Las Delicias', 'Ceibas', 'Villa Paranacito',
#        'Éjido Segundo Cuartel', 'Rosario Del Tala', 'Maciá', 'Durazno',
#        'Médanos', 'Ibicuy', 'Concepción Del Uruguay', 'Ruta 11 Km 212',
#        'Larroque', 'Aldea San Juan', 'Gualeguaychú', 'Costa Uruguay Sur'],
#       dtype=object)

# %%
df_entrerios.loc[df_entrerios["supervision"] == "Concordia Zona V - Cecilia Julieta Garcia", "localidad"] = "Concordia"
df_entrerios.loc[df_entrerios["supervision"] == "Federación Zona Xv - Clarisa Mabel Mela", "localidad"] = "Federación"

# %%
df_entrerios[df_entrerios["localidad"].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, codigo, fecha_nac, genero, jardin, sala, version_voc, version_conc_fono, version_sist_escrit, supervision, localidad, ocup_padres, comentarios, esp2022, concienciaFonologica2024, sistemaEscritura2024]
# Index: []

# %%
localidad_df = pd.DataFrame(df_entrerios["localidad"].unique(), columns=["localidad"])

# %%
localidad_df.sort_values(by="localidad", inplace=True)
# localidad_df

# %% [markdown]
# ### Detecto duplicados

# %%
# Hago un melt del df_entrerios para dejar un id por fila
df_melted = pd.melt(
    df_entrerios,
    id_vars=[
        "codigo",
        "fecha_nac",
        "genero",
        "jardin",
        "sala",
        "version_voc",
        "version_conc_fono",
        "version_sist_escrit",
        "supervision",
        "localidad",
        "ocup_padres",
        "comentarios"
    ],
    value_vars=["sistemaEscritura2024", "concienciaFonologica2024", "esp2022"],
    var_name="test_name",
    value_name="test_id",
    col_level=None,
    ignore_index=True
)
df_melted.shape
# Out:
# (2064, 14)

# %%
df_melted = df_melted[df_melted["test_id"] != "0-0000"]
df_melted.shape
# Out:
# (2008, 14)

# %%
# # Buscar filas duplicadas según "test_id"
duplicados_df = df_melted[df_melted.duplicated(subset="test_id", keep=False)]
duplicados_df.sort_values(by="codigo")
# duplicados=duplicados_df.test_id.unique()

duplicados_df.sort_values(by="codigo", inplace=True)
duplicados_df
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_16644\1034162959.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicados_df.sort_values(by="codigo", inplace=True)
#           codigo   fecha_nac     genero             jardin         sala  \
# 0      ER2410101  21/05/2019  Masculino          Ueni N 69  SALA 5 AÑOS
# 1      ER2410102  07/11/2018  Masculino          Ueni N 69  SALA 5 AÑOS
# 689    ER2410102  07/11/2018  Masculino          Ueni N 69  SALA 5 AÑOS
# 1377   ER2410102  07/11/2018  Masculino          Ueni N 69  SALA 5 AÑOS
# 2      ER2410103  19/08/2018  Masculino          Ueni N 69  SALA 5 AÑOS
# 1378   ER2410103  19/08/2018  Masculino          Ueni N 69  SALA 5 AÑOS
# 690    ER2410103  19/08/2018  Masculino          Ueni N 69  SALA 5 AÑOS
# 230    ER2411525  28/08/2018   Femenino    Priv Ueni N 057            5
# 1607   ER2411526  25/12/2018   Femenino    Priv Ueni N 057            5
# 969    ER2411719  10/04/2019  Masculino          Ueni N 65            G
# 1658   ER2411720  13/05/2019   Femenino          Ueni N 65            G
# 351    ER2412313  29/07/2018   Femenino  Esc Edu Prim N 52   Mojarritas
# 1728   ER2412314  28/08/2018   Femenino  Esc Edu Prim N 52   Mojarritas
# 408    ER2412701  04/10/2018   Femenino  Esc Edu Prim N 92            5
# 1096   ER2412701  04/10/2018   Femenino  Esc Edu Prim N 92            5
# 1785   ER2412702  24/01/2019   Femenino  Esc Edu Prim N 92            5
# 1793   ER2412709  22/02/2019  Masculino  Esc Edu Prim N 67            5
# 1105   ER2412709  22/02/2019  Masculino  Esc Edu Prim N 67            5
# 1120  ER2412811   12/01/2019   Femenino     Esc Prim N 198          NaN
# 432   ER2412811   12/01/2019   Femenino     Esc Prim N 198          NaN
# 1122   ER2412813  07/12/2018   Femenino          Ueni N 25          NaN
# 434    ER2412813  07/12/2018   Femenino          Ueni N 25          NaN
# 1132   ER2412823  02/10/2018  Masculino          Ueni N 18          NaN
# 444    ER2412823  02/10/2018  Masculino          Ueni N 18          NaN
# 1279   ER2413705  27/10/2018   Femenino   Esc Edu Prim N 1            F
# 591    ER2413705  27/10/2018   Femenino   Esc Edu Prim N 1            F
# 1363   ER2414402  16/03/2019  Masculino          Ueni N 16          5TM
# 1364   ER2414403  23/07/2018   Femenino  Esc Edu Prim N 92          5TM
# 677    ER2414404  15/08/2018  Masculino  Esc Edu Prim N 92          5TT
# 1365   ER2414404  15/08/2018  Masculino  Esc Edu Prim N 92          5TT
# 1375   ER2414414  21/03/2019   Femenino          Ueni N 16          5TM
# 687    ER2414414  21/03/2019   Femenino          Ueni N 16          5TM
# 2063   ER2414414  21/03/2019   Femenino          Ueni N 16          5TM
# 322    ER2420104  17/01/2019  Masculino          Ueni N 41  sala 5 años
# 1700   ER2420106  15/05/2019   Femenino          Ueni N 41  sala 5 años
# 1296    ER243903  15/03/2019  Masculino           Ueni N 1    5 años TM
# 608     ER243903  15/03/2019  Masculino           Ueni N 1    5 años TM
#
#      version_voc version_conc_fono version_sist_escrit  \
# 0              A                 A                   A
# 1              A                 A                   A
# 689            A                 A                   A
# 1377           A                 A                   A
# 2              A                 A                   A
# 1378           A                 A                   A
# 690            A                 A                   A
# 230            A                 A                   A
# 1607           B                 B                 NaN
# 969            A                 A                   A
# 1658           B                 B                   B
# 351            B                 B                   B
# 1728           A                 A                   A
# 408            A                 A                   A
# 1096           A                 A                   A
# 1785           B                 B                   B
# 1793           B                 B                   B
# 1105           B                 B                   B
# 1120           B                 B                   B
# 432            B                 B                   B
# 1122           A                 A                   A
# 434            A                 A                   A
# 1132           A                 A                   A
# 444            A                 A                   A
# 1279           B                 A                   B
# 591            B                 A                   B
# 1363           B                 B                   B
# 1364           A                 A                   A
# 677            B                 B                   B
# 1365           B                 B                   B
# 1375           A                 A                   A
# 687            A                 A                   A
# 2063           A                 A                   A
# 322            A                 A                   A
# 1700           A                 A                   A
# 1296           A                 A                   B
# 608            A                 A                   B
#
#                                           supervision               localidad  \
# 0     Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 1     Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 689   Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 1377  Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 2     Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 1378  Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 690   Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 230                                   Gestion Privada                San Jose
# 1607                                  Gestion Privada                San Jose
# 969          Diamante Zona Xii - Miriam Elena Retegui                 Chajari
# 1658         Diamante Zona Xii - Miriam Elena Retegui                 Chajari
# 351          Diamante Zona Xii - Miriam Elena Retegui                Diamante
# 1728         Diamante Zona Xii - Miriam Elena Retegui                Diamante
# 408               Nogoyá Zona Viii - Nancy Kergaravat                  Nogoyá
# 1096              Nogoyá Zona Viii - Nancy Kergaravat                  Nogoyá
# 1785              Nogoyá Zona Viii - Nancy Kergaravat                  Nogoyá
# 1793              Nogoyá Zona Viii - Nancy Kergaravat          Crucecitas 3Ra
# 1105              Nogoyá Zona Viii - Nancy Kergaravat          Crucecitas 3Ra
# 1120               Parana Zona I - Ana Delia González                  Paraná
# 432                Parana Zona I - Ana Delia González                  Paraná
# 1122                       Parana Zona Xx - Mabel Sea      Colónia Avellaneda
# 434                        Parana Zona Xx - Mabel Sea      Colónia Avellaneda
# 1132                       Parana Zona Xx - Mabel Sea                  Paraná
# 444                        Parana Zona Xx - Mabel Sea                  Paraná
# 1279                   Tala Zona Xvii - Mónica Londra        Rosario Del Tala
# 591                    Tala Zona Xvii - Mónica Londra        Rosario Del Tala
# 1363         Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
# 1364         Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
# 677          Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
# 1365         Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
# 1375         Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
# 687          Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
# 2063         Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
# 322                        Parana Zona Xx - Mabel Sea               Hasemkamp
# 1700                       Parana Zona Xx - Mabel Sea               Hasemkamp
# 1296         Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
# 608          Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
#
#                    ocup_padres  \
# 0                  AMA DE CASA
# 1                  AMA DE CASA
# 689                AMA DE CASA
# 1377               AMA DE CASA
# 2                  AMA DE CASA
# 1378               AMA DE CASA
# 690                AMA DE CASA
# 230                   empleado
# 1607                  empleado
# 969                   EMPLEADO
# 1658                  EMPLEADO
# 351                        NaN
# 1728                       NaN
# 408                    albañil
# 1096                   albañil
# 1785               ama de casa
# 1793         prod agropecuario
# 1105         prod agropecuario
# 1120                       NaN
# 432                        NaN
# 1122                       NaN
# 434                        NaN
# 1132                       NaN
# 444                        NaN
# 1279                  EMPLEADO
# 591                   EMPLEADO
# 1363                       NaN
# 1364                       NaN
# 677                        NaN
# 1365                       NaN
# 1375                       NaN
# 687                        NaN
# 2063                       NaN
# 322   Empleado público/Docente
# 1700      Estudiante/Apicultor
# 1296                       NaN
# 608                        NaN
#
#                                             comentarios  \
# 0                                                   NaN
# 1                                                   NaN
# 689                                                 NaN
# 1377                                                NaN
# 2                                                   NaN
# 1378                                                NaN
# 690                                                 NaN
# 230                                                 NaN
# 1607   La niña/o presionó espontáneamente el juego, ...
# 969                                                 NaN
# 1658                                                NaN
# 351                              Ama de Casa - Pescador
# 1728                             Ama de Casa - Empleado
# 408                                                 NaN
# 1096                                                NaN
# 1785                                                NaN
# 1793                                                NaN
# 1105                                                NaN
# 1120                                                NaN
# 432                                                 NaN
# 1122                                                NaN
# 434                                                 NaN
# 1132                                                NaN
# 444                                                 NaN
# 1279                                                NaN
# 591                                                 NaN
# 1363                                                NaN
# 1364                                                NaN
# 677                                                 NaN
# 1365                                                NaN
# 1375                                                NaN
# 687                                                 NaN
# 2063                                                NaN
# 322                                                 NaN
# 1700                                                NaN
# 1296                                                NaN
# 608                                                 NaN
#
#                      test_name    test_id
# 0         sistemaEscritura2024  3853-0012
# 1         sistemaEscritura2024  3853-0012
# 689   concienciaFonologica2024  3853-0012
# 1377                   esp2022  3853-0012
# 2         sistemaEscritura2024  3853-0015
# 1378                   esp2022  3853-0015
# 690   concienciaFonologica2024  3853-0015
# 230       sistemaEscritura2024  4360-0155
# 1607                   esp2022  4360-0155
# 969   concienciaFonologica2024  6567-0098
# 1658                   esp2022  6567-0098
# 351       sistemaEscritura2024  5837-0041
# 1728                   esp2022  5837-0041
# 408       sistemaEscritura2024  2967-0007
# 1096  concienciaFonologica2024  2967-0007
# 1785                   esp2022  2967-0007
# 1793                   esp2022  2967-0031
# 1105  concienciaFonologica2024  2967-0031
# 1120  concienciaFonologica2024  2967-0084
# 432       sistemaEscritura2024  2967-0084
# 1122  concienciaFonologica2024  2967-0089
# 434       sistemaEscritura2024  2967-0089
# 1132  concienciaFonologica2024  2967-0119
# 444       sistemaEscritura2024  2967-0119
# 1279  concienciaFonologica2024  6564-0084
# 591       sistemaEscritura2024  6564-0084
# 1363  concienciaFonologica2024  6577-0000
# 1364  concienciaFonologica2024  4360-0000
# 677       sistemaEscritura2024  4360-0000
# 1365  concienciaFonologica2024  4360-0000
# 1375  concienciaFonologica2024  6577-0000
# 687       sistemaEscritura2024  6577-0000
# 2063                   esp2022  6577-0000
# 322       sistemaEscritura2024  5837-0171
# 1700                   esp2022  5837-0171
# 1296  concienciaFonologica2024  6577-0114
# 608       sistemaEscritura2024  6577-0114

# %% [markdown]
# #### Dejo las duplicadas para luego quedarme con la correcta cuando hago el merge. La incorrecta por ahora se pierde

# %% [markdown]
# ### Cargo la data del server y elimino duplicados

# %%
df_server = pd.read_csv("data_server_entrerios.csv")  
df_server.drop_duplicates(inplace=True)
df_server.shape
# Out:
# (54814, 25)

# %% [markdown]
# #### Saco los ítems fáciles, las pruebas de entrenamiento y > 7000 ms -> correcto = 0

# %%
df_server = df_server.drop(df_server[df_server["level_name"] == "entrenamiento"].index)


lista_faciles = [
    "esp2022-mochila",
    "esp2022-pantalon",
    "esp2022-limpio",
    "esp2022-gato",
    "esp2022-caballo",
    "esp2022-casa",
    "esp2022-anteojo",
    "esp2022-dormir",
    "esp2022-rojo",
    "esp2022-lapiz",
    "esp2022-llorar"
]

df_server = df_server[~df_server["object1_name"].isin(lista_faciles)]
df_server.shape
# Out:
# (41882, 25)

# %%
df_server.query("correct == 1").shape
# Out:
# (36480, 25)

# %%
df_server.loc[ df_server.query("object_touched_at > 7000").index, "correct" ] = 0
df_server.query("correct == 1").shape
# Out:
# (33328, 25)

# %% [markdown]
# ### Unifico valores de test_name

# %%
test_map = {
       'sistemaEscritura2024-16':'sistemaEscritura2024-B',
       'sistemaEscritura2024-15': 'sistemaEscritura2024-A',
       'esp2022-5' :'esp2022-A',
       'esp2022-6':'esp2022-B',
       'concienciaFonologica2024-2':"concienciaFonologica2024-B",
       'concienciaFonologica2024-1':'concienciaFonologica2024-A'}

df_server['test_name'] = df_server['test_name'].replace(test_map)

df_server.test_name.unique()
# Out:
# array(['concienciaFonologica2024-A', 'concienciaFonologica2024-B',
#        'sistemaEscritura2024-A', 'sistemaEscritura2024-B', 'esp2022-A',
#        'esp2022-B'], dtype=object)

# %%
# 1. Crear la nueva columna 'version'
df_server["version"] = df_server["test_name"].str.split("-").str[-1]

# %%
# 1. Elimino la versión de la columna test_name
df_server["test_name"] = df_server["test_name"].str.split("-").str[0]
df_server
# Out:
#                                    uuid    test_id                 test_name  \
# 3      75D4A1A435004302ADDFC6FE5CC54E6D  5845-0005  concienciaFonologica2024
# 4      75D4A1A435004302ADDFC6FE5CC54E6D  5845-0005  concienciaFonologica2024
# 5      75D4A1A435004302ADDFC6FE5CC54E6D  5845-0005  concienciaFonologica2024
# 6      75D4A1A435004302ADDFC6FE5CC54E6D  5845-0005  concienciaFonologica2024
# 7      75D4A1A435004302ADDFC6FE5CC54E6D  5845-0005  concienciaFonologica2024
# ...                                 ...        ...                       ...
# 71588  62EAF2D1E718452BAFA95404A24E91D1  5295-0175  concienciaFonologica2024
# 71589  62EAF2D1E718452BAFA95404A24E91D1  5295-0175  concienciaFonologica2024
# 71590  62EAF2D1E718452BAFA95404A24E91D1  5295-0175  concienciaFonologica2024
# 71591  62EAF2D1E718452BAFA95404A24E91D1  5295-0175  concienciaFonologica2024
# 71592  62EAF2D1E718452BAFA95404A24E91D1  5295-0175  concienciaFonologica2024
#
#        device        date        session_started_at          session_ended_at  \
# 3        5845  2024-11-12  2024-11-12T12:57:02.000Z  2024-11-12T13:07:34.000Z
# 4        5845  2024-11-12  2024-11-12T12:57:02.000Z  2024-11-12T13:07:34.000Z
# 5        5845  2024-11-12  2024-11-12T12:57:02.000Z  2024-11-12T13:07:34.000Z
# 6        5845  2024-11-12  2024-11-12T12:57:02.000Z  2024-11-12T13:07:34.000Z
# 7        5845  2024-11-12  2024-11-12T12:57:02.000Z  2024-11-12T13:07:34.000Z
# ...       ...         ...                       ...                       ...
# 71588    5295  2024-12-19  2024-12-19T16:44:24.000Z  2024-12-19T16:53:57.000Z
# 71589    5295  2024-12-19  2024-12-19T16:44:24.000Z  2024-12-19T16:53:57.000Z
# 71590    5295  2024-12-19  2024-12-19T16:44:24.000Z  2024-12-19T16:53:57.000Z
# 71591    5295  2024-12-19  2024-12-19T16:44:24.000Z  2024-12-19T16:53:57.000Z
# 71592    5295  2024-12-19  2024-12-19T16:44:24.000Z  2024-12-19T16:53:57.000Z
#
#        trial_number_session          trial_started_at  repetition  ...  \
# 3                         4  2024-11-12T12:58:46.926Z           0  ...
# 4                         5  2024-11-12T12:59:12.630Z           0  ...
# 5                         6  2024-11-12T12:59:38.233Z           0  ...
# 6                         7  2024-11-12T13:00:08.422Z           0  ...
# 7                         8  2024-11-12T13:00:32.798Z           0  ...
# ...                     ...                       ...         ...  ...
# 71588                    19  2024-12-19T16:51:42.718Z           0  ...
# 71589                    20  2024-12-19T16:52:12.847Z           0  ...
# 71590                    21  2024-12-19T16:52:46.084Z           0  ...
# 71591                    22  2024-12-19T16:53:09.948Z           0  ...
# 71592                    23  2024-12-19T16:53:32.384Z           0  ...
#
#                              object2_name mandy_touch_diff_time  \
# 3           concienciaFonologica2024-vaso                  4107
# 4           concienciaFonologica2024-azul                  3730
# 5        concienciaFonologica2024-cuchara                  9099
# 6            concienciaFonologica2024-uva                  3997
# 7            concienciaFonologica2024-ojo                   692
# ...                                   ...                   ...
# 71588  concienciaFonologica2024-bicicleta                   894
# 71589    concienciaFonologica2024-mochila                   171
# 71590   concienciaFonologica2024-guitarra                   980
# 71591     concienciaFonologica2024-arania                   757
# 71592       concienciaFonologica2024-mate                  1586
#
#                              object_asked  object_asked_position  \
# 3           concienciaFonologica2024-nido            CENTER_LEFT
# 4           concienciaFonologica2024-azul           CENTER_RIGHT
# 5       concienciaFonologica2024-empanada            CENTER_LEFT
# 6          concienciaFonologica2024-lapiz            CENTER_LEFT
# 7            concienciaFonologica2024-ojo           CENTER_RIGHT
# ...                                   ...                    ...
# 71588  concienciaFonologica2024-bicicleta           CENTER_RIGHT
# 71589   concienciaFonologica2024-elefante            CENTER_LEFT
# 71590   concienciaFonologica2024-guitarra           CENTER_RIGHT
# 71591     concienciaFonologica2024-arania           CENTER_RIGHT
# 71592       concienciaFonologica2024-mate           CENTER_RIGHT
#
#                           object_touched object_touched_position  \
# 3          concienciaFonologica2024-nido             CENTER_LEFT
# 4          concienciaFonologica2024-azul            CENTER_RIGHT
# 5      concienciaFonologica2024-empanada             CENTER_LEFT
# 6         concienciaFonologica2024-lapiz             CENTER_LEFT
# 7           concienciaFonologica2024-ojo            CENTER_RIGHT
# ...                                  ...                     ...
# 71588   concienciaFonologica2024-caballo             CENTER_LEFT
# 71589  concienciaFonologica2024-elefante             CENTER_LEFT
# 71590  concienciaFonologica2024-guitarra            CENTER_RIGHT
# 71591    concienciaFonologica2024-arania            CENTER_RIGHT
# 71592      concienciaFonologica2024-mate            CENTER_RIGHT
#
#       object_touched_at  correct count_rewards version
# 3                  1236        1             4       A
# 4                  1656        1             4       A
# 5                   860        1             4       A
# 6                    18        1             4       A
# 7                   563        1             4       A
# ...                 ...      ...           ...     ...
# 71588              9123        0             4       A
# 71589             12784        0             4       A
# 71590              2797        1             4       A
# 71591              1588        1             4       A
# 71592              1463        1             4       A
#
# [41882 rows x 26 columns]

# %% [markdown]
# #### Quedarte solo con correctas y sacar latency de eso

# %%
df_latency_correctas = df_server.query("correct == 1").groupby(["test_id","test_name"], as_index=False).agg(
    latency = ("object_touched_at", "mean")
)
df_latency_correctas
# Out:
#         test_id                 test_name      latency
# 0     1685-0002                   esp2022  2004.766667
# 1     1685-0003  concienciaFonologica2024  2858.750000
# 2     1685-0004      sistemaEscritura2024  2208.750000
# 3     2254-0001                   esp2022  4750.833333
# 4     2254-0002                   esp2022  3184.406250
# ...         ...                       ...          ...
# 1962  8447-0073      sistemaEscritura2024  1352.000000
# 1963  8447-0075                   esp2022  3769.750000
# 1964  8447-0076                   esp2022  2973.222222
# 1965  8447-0077                   esp2022  3413.962963
# 1966  8447-0079      sistemaEscritura2024  3160.000000
#
# [1967 rows x 3 columns]

# %% [markdown]
# #### Mergear las dos para obtener accuracy y latency_correctas

# %%
df = df_server.groupby(["test_id","test_name"], as_index=False).agg(
    
   
    cantidad_correctas = ("correct", "sum"),
    accuracy = ("correct", "mean"),
#   latency_general = ("object_touched_at", "mean"),
    attempts = ("correct", "count"),

    test_id = ("test_id", "first"),
    date = ("date", "first"),
    version = ("version", "first")
    
)
df
# Out:
#                      test_name  cantidad_correctas  accuracy  attempts  \
# 0                      esp2022                  30  0.882353        34
# 1     concienciaFonologica2024                   8  0.400000        20
# 2         sistemaEscritura2024                   4  0.400000        10
# 3                      esp2022                  18  0.529412        34
# 4                      esp2022                  32  0.941176        34
# ...                        ...                 ...       ...       ...
# 1965      sistemaEscritura2024                   9  0.900000        10
# 1966                   esp2022                   8  0.533333        15
# 1967                   esp2022                  27  0.794118        34
# 1968                   esp2022                  27  0.794118        34
# 1969      sistemaEscritura2024                   9  0.900000        10
#
#         test_id        date version
# 0     1685-0002  2024-12-04       A
# 1     1685-0003  2024-12-04       B
# 2     1685-0004  2024-12-04       A
# 3     2254-0001  2024-11-14       A
# 4     2254-0002  2024-11-14       B
# ...         ...         ...     ...
# 1965  8447-0073  2024-12-04       B
# 1966  8447-0075  2024-12-17       B
# 1967  8447-0076  2024-12-17       B
# 1968  8447-0077  2024-12-17       B
# 1969  8447-0079  2024-12-17       B
#
# [1970 rows x 7 columns]

# %%
df["count_max"] = 34
df.loc[ df["test_name"] == "sistemaEscritura2024", "count_max" ] = 10
df.loc[ df["test_name"] == "concienciaFonologica2024", "count_max" ] = 20
df
# Out:
#                      test_name  cantidad_correctas  accuracy  attempts  \
# 0                      esp2022                  30  0.882353        34
# 1     concienciaFonologica2024                   8  0.400000        20
# 2         sistemaEscritura2024                   4  0.400000        10
# 3                      esp2022                  18  0.529412        34
# 4                      esp2022                  32  0.941176        34
# ...                        ...                 ...       ...       ...
# 1965      sistemaEscritura2024                   9  0.900000        10
# 1966                   esp2022                   8  0.533333        15
# 1967                   esp2022                  27  0.794118        34
# 1968                   esp2022                  27  0.794118        34
# 1969      sistemaEscritura2024                   9  0.900000        10
#
#         test_id        date version  count_max
# 0     1685-0002  2024-12-04       A         34
# 1     1685-0003  2024-12-04       B         20
# 2     1685-0004  2024-12-04       A         10
# 3     2254-0001  2024-11-14       A         34
# 4     2254-0002  2024-11-14       B         34
# ...         ...         ...     ...        ...
# 1965  8447-0073  2024-12-04       B         10
# 1966  8447-0075  2024-12-17       B         34
# 1967  8447-0076  2024-12-17       B         34
# 1968  8447-0077  2024-12-17       B         34
# 1969  8447-0079  2024-12-17       B         10
#
# [1970 rows x 8 columns]

# %%
df["accuracy_totales"] = df["cantidad_correctas"] / df["count_max"] 
df_data= pd.merge(df, df_latency_correctas, on = ["test_id","test_name" ])
df_data
# Out:
#                      test_name  cantidad_correctas  accuracy  attempts  \
# 0                      esp2022                  30  0.882353        34
# 1     concienciaFonologica2024                   8  0.400000        20
# 2         sistemaEscritura2024                   4  0.400000        10
# 3                      esp2022                  18  0.529412        34
# 4                      esp2022                  32  0.941176        34
# ...                        ...                 ...       ...       ...
# 1962      sistemaEscritura2024                   9  0.900000        10
# 1963                   esp2022                   8  0.533333        15
# 1964                   esp2022                  27  0.794118        34
# 1965                   esp2022                  27  0.794118        34
# 1966      sistemaEscritura2024                   9  0.900000        10
#
#         test_id        date version  count_max  accuracy_totales      latency
# 0     1685-0002  2024-12-04       A         34          0.882353  2004.766667
# 1     1685-0003  2024-12-04       B         20          0.400000  2858.750000
# 2     1685-0004  2024-12-04       A         10          0.400000  2208.750000
# 3     2254-0001  2024-11-14       A         34          0.529412  4750.833333
# 4     2254-0002  2024-11-14       B         34          0.941176  3184.406250
# ...         ...         ...     ...        ...               ...          ...
# 1962  8447-0073  2024-12-04       B         10          0.900000  1352.000000
# 1963  8447-0075  2024-12-17       B         34          0.235294  3769.750000
# 1964  8447-0076  2024-12-17       B         34          0.794118  2973.222222
# 1965  8447-0077  2024-12-17       B         34          0.794118  3413.962963
# 1966  8447-0079  2024-12-17       B         10          0.900000  3160.000000
#
# [1967 rows x 10 columns]

# %%
df_data.query('attempts >34')
df_data = df_data.drop( columns = ["count_max", "cantidad_correctas"] )

# %%
# Buscar filas duplicadas según "test_id"
duplicados_server = df_data[df_data.duplicated(subset="test_id", keep=False)]
duplicados_server
# Out:
# Empty DataFrame
# Columns: [test_name, accuracy, attempts, test_id, date, version, accuracy_totales, latency]
# Index: []

# %%
df_data["id_and_test"]= df_data["test_id"] + df_data["test_name"]
df_melted["id_and_test"]= df_melted["test_id"] + df_melted["test_name"]

# %%
df_melted.shape
# Out:
# (2008, 15)

# %%
# Filtrar los valores de df_melt que no están en df_data
valores_faltantes = df_melted[~df_melted["id_and_test"].isin(df_data["id_and_test"])]
valores_faltantes
# valores_faltantes.to_csv("faltantes.csv")
# Out:
#          codigo   fecha_nac     genero                  jardin         sala  \
# 0     ER2410101  21/05/2019  Masculino               Ueni N 69  SALA 5 AÑOS
# 1     ER2410102  07/11/2018  Masculino               Ueni N 69  SALA 5 AÑOS
# 2     ER2410103  19/08/2018  Masculino               Ueni N 69  SALA 5 AÑOS
# 5     ER2410106  17/12/2018   Femenino        Esc Edu Prim N 1  SALA 5 AÑOS
# 6     ER2410107  03/07/2018  Masculino        Esc Edu Prim N 1  SALA 5 AÑOS
# ...         ...         ...        ...                     ...          ...
# 1942  ER2413507  21/11/2018  Masculino  Esc Prim N 8 (Federal)       5 Años
# 1944  ER2413509  29/09/2018   Femenino         Priv Ueni N 191       5 Años
# 1946  ER2413511  11/07/2018   Femenino               Ueni N 11       5 Años
# 1983   ER243902  19/07/2018   Femenino               Ueni N 16    5 años TT
# 2063  ER2414414  21/03/2019   Femenino               Ueni N 16          5TM
#
#      version_voc version_conc_fono version_sist_escrit  \
# 0              A                 A                   A
# 1              A                 A                   A
# 2              A                 A                   A
# 5              B                 B                   B
# 6              B                 B                   B
# ...          ...               ...                 ...
# 1942           A                 A                   A
# 1944           A                 A                   A
# 1946           A                 A                   A
# 1983           A                 A                   A
# 2063           A                 A                   A
#
#                                           supervision               localidad  \
# 0     Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 1     Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 2     Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 5     Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# 6     Feliciano Zona Xviii - María Jorgelina Paniagua   San José De Feliciano
# ...                                               ...                     ...
# 1942                Federal Zona Vi - Betina Inés Ava     Paraje Las Delicias
# 1944                   Islas Zona Xiv -Jacinta Maciel                  Ceibas
# 1946                   Islas Zona Xiv -Jacinta Maciel        Villa Paranacito
# 1983         Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
# 2063         Uruguay Zona Iv - Silvina Daniela Suarez  Concepción Del Uruguay
#
#         ocup_padres comentarios             test_name    test_id  \
# 0       AMA DE CASA         NaN  sistemaEscritura2024  3853-0012
# 1       AMA DE CASA         NaN  sistemaEscritura2024  3853-0012
# 2       AMA DE CASA         NaN  sistemaEscritura2024  3853-0015
# 5       AMA DE CASA         NaN  sistemaEscritura2024  3853-0026
# 6           POLICIA         NaN  sistemaEscritura2024  3853-0029
# ...             ...         ...                   ...        ...
# 1942  Empeado rural         NaN               esp2022  2254-0072
# 1944        Policía         NaN               esp2022  2254-0079
# 1946       Empleado         NaN               esp2022  2254-0085
# 1983            NaN         NaN               esp2022  6577-0104
# 2063            NaN         NaN               esp2022  6577-0000
#
#                         id_and_test
# 0     3853-0012sistemaEscritura2024
# 1     3853-0012sistemaEscritura2024
# 2     3853-0015sistemaEscritura2024
# 5     3853-0026sistemaEscritura2024
# 6     3853-0029sistemaEscritura2024
# ...                             ...
# 1942               2254-0072esp2022
# 1944               2254-0079esp2022
# 1946               2254-0085esp2022
# 1983               6577-0104esp2022
# 2063               6577-0000esp2022
#
# [106 rows x 15 columns]

# %%
valores_unicos = set(df_melted["id_and_test"]) - set(df_data["id_and_test"])
valores_faltantes = df_melted[df_melted["id_and_test"].isin(valores_unicos)]
valores_faltantes.shape
# Out:
# (106, 15)

# %%
valores_faltantes.to_csv("errores_planillas.csv")

# %%
valores_faltantes["op"] = valores_faltantes.codigo.str[5:7]
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_16644\2856162819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valores_faltantes["op"] = valores_faltantes.codigo.str[5:7]

# %%
valores_faltantes.value_counts("op")
# Out:
# op
# 35    14
# 01    13
# 05     9
# 44     8
# 60     6
# 90     6
# 07     6
# 32     5
# 22     4
# 27     4
# 28     4
# 61     3
# 16     3
# 12     3
# 38     3
# 17     2
# 19     2
# 14     2
# 15     1
# 37     1
# 29     1
# 13     1
# 33     1
# 30     1
# 23     1
# 18     1
# 24     1
# dtype: int64

# %%
# valores_faltantes.query("op=='44'")

# %%
df_data.query('test_id == "6755-0087"')
# Out:
# Empty DataFrame
# Columns: [test_name, accuracy, attempts, test_id, date, version, accuracy_totales, latency, id_and_test]
# Index: []

# %%
df_melted.shape
# Out:
# (2008, 15)

# %%
df_melted[ ~df_melted.duplicated(subset="test_id") ].shape
# Out:
# (1986, 15)

# %%
# df_data.merge(df_melted[ ~df_melted.duplicated(subset="test_id") ], on="test_id", how="inner")

# %%
merged_df=df_data.merge(df_melted, on="id_and_test", how="inner")

# %% [markdown]
# * Caso solo entrenamiento
# * Caso id que no corresponde con el server
# * Caso que no estan las pruebas en el server

# %%
merged_df
# Out:
#                    test_name_x  accuracy  attempts  test_id_x        date  \
# 0                      esp2022  0.882353        34  1685-0002  2024-12-04
# 1     concienciaFonologica2024  0.400000        20  1685-0003  2024-12-04
# 2         sistemaEscritura2024  0.400000        10  1685-0004  2024-12-04
# 3                      esp2022  0.529412        34  2254-0001  2024-11-14
# 4                      esp2022  0.941176        34  2254-0002  2024-11-14
# ...                        ...       ...       ...        ...         ...
# 1897                   esp2022  0.941176        34  8447-0072  2024-12-04
# 1898      sistemaEscritura2024  0.900000        10  8447-0073  2024-12-04
# 1899                   esp2022  0.533333        15  8447-0075  2024-12-17
# 1900                   esp2022  0.794118        34  8447-0076  2024-12-17
# 1901                   esp2022  0.794118        34  8447-0077  2024-12-17
#
#      version  accuracy_totales      latency  \
# 0          A          0.882353  2004.766667
# 1          B          0.400000  2858.750000
# 2          A          0.400000  2208.750000
# 3          A          0.529412  4750.833333
# 4          B          0.941176  3184.406250
# ...      ...               ...          ...
# 1897       B          0.941176  2574.562500
# 1898       B          0.900000  1352.000000
# 1899       B          0.235294  3769.750000
# 1900       B          0.794118  2973.222222
# 1901       B          0.794118  3413.962963
#
#                             id_and_test     codigo  ...       sala  \
# 0                      1685-0002esp2022  ER2413711  ...  MULTIEDAD
# 1     1685-0003concienciaFonologica2024  ER2413711  ...  MULTIEDAD
# 2         1685-0004sistemaEscritura2024  ER2413711  ...  MULTIEDAD
# 3                      2254-0001esp2022  ER2413401  ...     verde
# 4                      2254-0002esp2022  ER2413402  ...      verde
# ...                                 ...        ...  ...        ...
# 1897                   8447-0072esp2022  ER2411104  ...          5
# 1898      8447-0073sistemaEscritura2024  ER2411104  ...          5
# 1899                   8447-0075esp2022  ER2412203  ...     5 años
# 1900                   8447-0076esp2022  ER2412202  ...     5 años
# 1901                   8447-0077esp2022  ER2412201  ...     5 años
#
#      version_voc version_conc_fono version_sist_escrit  \
# 0              A                 B                   A
# 1              A                 B                   A
# 2              A                 B                   A
# 3              A                 A                   A
# 4              B                 B                   B
# ...          ...               ...                 ...
# 1897           B                 B                   B
# 1898           B                 B                   B
# 1899           A                 A                   A
# 1900           B                 B                   B
# 1901           A                 A                   A
#
#                                     supervision  localidad  ocup_padres  \
# 0                Tala Zona Xvii - Mónica Londra    Durazno     EMPLEADO
# 1                Tala Zona Xvii - Mónica Londra    Durazno     EMPLEADO
# 2                Tala Zona Xvii - Mónica Londra    Durazno     EMPLEADO
# 3      Diamante Zona Xii - Miriam Elena Retegui   Diamante  Ama de casa
# 4      Diamante Zona Xii - Miriam Elena Retegui   Diamante      Policia
# ...                                         ...        ...          ...
# 1897  Concordia Zona V - Cecilia Julieta Garcia  Concordia  ama de casa
# 1898  Concordia Zona V - Cecilia Julieta Garcia  Concordia  ama de casa
# 1899       Parana  Zona Ii - Claudio G. Lomagno     Paraná          NaN
# 1900       Parana  Zona Ii - Claudio G. Lomagno     Paraná          NaN
# 1901       Parana  Zona Ii - Claudio G. Lomagno     Paraná          NaN
#
#                                             comentarios  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Es un niño con TE, asiste al jardín con su aco...
# 4                                                   NaN
# ...                                                 ...
# 1897                                  PRIMARIO COMPLETO
# 1898                                  PRIMARIO COMPLETO
# 1899                                                NaN
# 1900                                                NaN
# 1901                                                NaN
#
#                    test_name_y  test_id_y
# 0                      esp2022  1685-0002
# 1     concienciaFonologica2024  1685-0003
# 2         sistemaEscritura2024  1685-0004
# 3                      esp2022  2254-0001
# 4                      esp2022  2254-0002
# ...                        ...        ...
# 1897                   esp2022  8447-0072
# 1898      sistemaEscritura2024  8447-0073
# 1899                   esp2022  8447-0075
# 1900                   esp2022  8447-0076
# 1901                   esp2022  8447-0077
#
# [1902 rows x 23 columns]

# %% [markdown]
# ### Elijo columnas

# %%
merged_df = merged_df[[
 'test_name_x',
    'version',
    'test_id_x',
     
    'accuracy',
    'accuracy_totales',
    'attempts',
    'latency',    
    'date',
    
    'codigo',    
    'fecha_nac',    
    'genero',
    'jardin',
    'sala',
    'supervision',
    'localidad',
    'ocup_padres',    
    'comentarios'
 #     'id_and_test',
]]

merged_df.rename(columns= {'test_name_x':"test_name", 'test_id_x': 'test_id'} )
# Out:
#                      test_name version    test_id  accuracy  accuracy_totales  \
# 0                      esp2022       A  1685-0002  0.882353          0.882353
# 1     concienciaFonologica2024       B  1685-0003  0.400000          0.400000
# 2         sistemaEscritura2024       A  1685-0004  0.400000          0.400000
# 3                      esp2022       A  2254-0001  0.529412          0.529412
# 4                      esp2022       B  2254-0002  0.941176          0.941176
# ...                        ...     ...        ...       ...               ...
# 1897                   esp2022       B  8447-0072  0.941176          0.941176
# 1898      sistemaEscritura2024       B  8447-0073  0.900000          0.900000
# 1899                   esp2022       B  8447-0075  0.533333          0.235294
# 1900                   esp2022       B  8447-0076  0.794118          0.794118
# 1901                   esp2022       B  8447-0077  0.794118          0.794118
#
#       attempts      latency        date     codigo   fecha_nac     genero  \
# 0           34  2004.766667  2024-12-04  ER2413711  25/03/2019  Masculino
# 1           20  2858.750000  2024-12-04  ER2413711  25/03/2019  Masculino
# 2           10  2208.750000  2024-12-04  ER2413711  25/03/2019  Masculino
# 3           34  4750.833333  2024-11-14  ER2413401  02/10/2018  Masculino
# 4           34  3184.406250  2024-11-14  ER2413402  17/09/2018   Femenino
# ...        ...          ...         ...        ...         ...        ...
# 1897        34  2574.562500  2024-12-04  ER2411104  03/05/2019   Femenino
# 1898        10  1352.000000  2024-12-04  ER2411104  03/05/2019   Femenino
# 1899        15  3769.750000  2024-12-17  ER2412203  15/08/2018   Femenino
# 1900        34  2973.222222  2024-12-17  ER2412202  23/10/2018   Femenino
# 1901        34  3413.962963  2024-12-17  ER2412201  15/03/2019   Femenino
#
#                  jardin       sala                                supervision  \
# 0     Esc Edu Prim N 35  MULTIEDAD             Tala Zona Xvii - Mónica Londra
# 1     Esc Edu Prim N 35  MULTIEDAD             Tala Zona Xvii - Mónica Londra
# 2     Esc Edu Prim N 35  MULTIEDAD             Tala Zona Xvii - Mónica Londra
# 3             Ueni N 57     verde    Diamante Zona Xii - Miriam Elena Retegui
# 4             Ueni N 57      verde   Diamante Zona Xii - Miriam Elena Retegui
# ...                 ...        ...                                        ...
# 1897  Esc Edu Prim N 36          5  Concordia Zona V - Cecilia Julieta Garcia
# 1898  Esc Edu Prim N 36          5  Concordia Zona V - Cecilia Julieta Garcia
# 1899  Esc Edu Prim N 23     5 años       Parana  Zona Ii - Claudio G. Lomagno
# 1900  Esc Edu Prim N 23     5 años       Parana  Zona Ii - Claudio G. Lomagno
# 1901  Esc Edu Prim N 23     5 años       Parana  Zona Ii - Claudio G. Lomagno
#
#       localidad  ocup_padres  \
# 0       Durazno     EMPLEADO
# 1       Durazno     EMPLEADO
# 2       Durazno     EMPLEADO
# 3      Diamante  Ama de casa
# 4      Diamante      Policia
# ...         ...          ...
# 1897  Concordia  ama de casa
# 1898  Concordia  ama de casa
# 1899     Paraná          NaN
# 1900     Paraná          NaN
# 1901     Paraná          NaN
#
#                                             comentarios
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Es un niño con TE, asiste al jardín con su aco...
# 4                                                   NaN
# ...                                                 ...
# 1897                                  PRIMARIO COMPLETO
# 1898                                  PRIMARIO COMPLETO
# 1899                                                NaN
# 1900                                                NaN
# 1901                                                NaN
#
# [1902 rows x 17 columns]

# %%
merged_df.attempts.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Saco attempts menores al 10% redondeando para abajo del total de cada prueba
#     Vocabulario (2022): 45 ejercicios (finalmente usamos 34, que es sin las faciles)
#     Conciencia fonológica (2024): 20 ejercicios
#     Sistema de escritura (2024): 10 ejercicios

# %%
merged_df.test_name_x.unique()
# Out:
# array(['esp2022', 'concienciaFonologica2024', 'sistemaEscritura2024'],
#       dtype=object)

# %% [markdown]
# #### Vocabulario

# %%
merged_df.query("attempts <= 3 and test_name_x == 'esp2022'").shape
# Out:
# (0, 17)

# %% [markdown]
# #### Sistema de escritura

# %%
merged_df.query("attempts <= 1 and test_name_x == 'sistemaEscritura2024'").shape
# Out:
# (0, 17)

# %% [markdown]
# #### Conciencia Fonológica

# %%
merged_df.shape
# Out:
# (1902, 17)

# %%
merged_df.query("attempts <= 2 and test_name_x == 'concienciaFonologica2024'").shape
# Out:
# (1, 17)

# %%
merged_df = merged_df.drop( merged_df.query("attempts <= 2 and test_name_x == 'concienciaFonologica2024'").index )

# %%
merged_df.shape
# Out:
# (1901, 17)

# %% [markdown]
# #### Fin

# %%
merged_df.attempts.value_counts(dropna=False)
# Out:
# 34    644
# 20    618
# 10    599
# 9      18
# 19      4
# 8       3
# 26      2
# 6       2
# 7       2
# 5       1
# 16      1
# 21      1
# 23      1
# 18      1
# 11      1
# 12      1
# 14      1
# 15      1
# Name: attempts, dtype: int64

# %% [markdown]
# Dado la cantidad de ejercicios que está más arriba los número parecerían estar bien

# %% [markdown]
# ## Edad

# %%
fechas_nacimiento = merged_df.fecha_nac.str.replace("-","/").str.split("/", expand=True)

# %%
fechas_nacimiento = fechas_nacimiento.rename(columns={2: "año"})
df_filtrado = fechas_nacimiento.query('año.str.len() > 4')

fechas_nacimiento.loc[fechas_nacimiento["año"] == "29018", "año"] = "2018"
fechas_nacimiento.loc[fechas_nacimiento["año"] == "2918", "año"] = "2018"
fechas_nacimiento.loc[fechas_nacimiento["año"] == "2028", "año"] = "2018"
fechas_nacimiento.loc[fechas_nacimiento["año"] == "2029", "año"] = "2019"

fechas_nacimiento.loc[fechas_nacimiento["año"] == "20 19", "año"] = "2019"
fechas_nacimiento.loc[fechas_nacimiento["año"] == "20218", "año"] = "2018"
fechas_nacimiento.loc[fechas_nacimiento["año"] == "20219", "año"] = "2019"

# %%
fechas_nacimiento = fechas_nacimiento.rename(columns={"año": 2 })

# %% [markdown]
# ### Pongo en el formato que corresponde

# %%
fechas_nacimiento[0] = fechas_nacimiento[0].str.strip()
fechas_nacimiento[1] = fechas_nacimiento[1].str.strip()
fechas_nacimiento[2] = fechas_nacimiento[2].str.strip()

# %% [markdown]
# #### Hay años que estan en 2 dígitos en vez de en 4

# %%
fechas_nacimiento[ fechas_nacimiento[2].str.len() == 2 ][2].value_counts(dropna=False)
# Out:
# Series([], Name: 2, dtype: int64)

# %%
fechas_nacimiento.loc[ fechas_nacimiento[2].str.len() == 2, 2] = "20" + fechas_nacimiento.loc[ fechas_nacimiento[2].str.len() == 2, 2]

# %%
fechas_nacimiento[ fechas_nacimiento[2].str.len() != 4 ].value_counts(dropna=False)
# Out:
# 0           1    2
# 05          03   20 19    3
# 1271272018  NaN  NaN      3
# NaN         NaN  NaN      3
# dtype: int64

# %%
fechas_nacimiento.loc[ fechas_nacimiento[2] == "20 19", 2 ] = "2019"

# %%
fechas_nacimiento[ fechas_nacimiento[2].str.len() != 4 ].value_counts(dropna=False)
# Out:
# 0           1    2
# 1271272018  NaN  NaN    3
# NaN         NaN  NaN    3
# dtype: int64

# %%
fechas_nacimiento.loc[ fechas_nacimiento[0] == "1271272018", 0 ] = None

# %%
fechas_nacimiento[ fechas_nacimiento[2].str.len() != 4 ].value_counts(dropna=False)
# Out:
# 0    1    2
# NaN  NaN  NaN    6
# dtype: int64

# %% [markdown]
# #### Hay tres dias que están mal

# %%
# fechas_nacimiento[ fechas_nacimiento[0].str.len() == 3 ]

# %%
# fechas_nacimiento.loc[ fechas_nacimiento[0].str.len() == 3, 0 ] = "22"

# %% [markdown]
# #### Check

# %%
fechas_nacimiento[ fechas_nacimiento[0].str.len() != 2 ]
# Out:
#         0     1     2
# 49   None  None  None
# 52   None  None  None
# 53   None  None  None
# 267   NaN   NaN   NaN
# 539   NaN   NaN   NaN
# 540   NaN   NaN   NaN

# %%
fechas_nacimiento[2].unique()
# Out:
# array(['2019', '2018', None, '2024', nan], dtype=object)

# %% [markdown]
# ### Estamos ok

# %%
# Convertir a string y crear la columna de fecha
fechas_nacimiento["fecha_nacimiento"] = fechas_nacimiento[0].astype(str) + "-" + \
                                        fechas_nacimiento[1].astype(str) + "-" + \
                                        fechas_nacimiento[2].astype(str)

# Mostrar las primeras filas
fechas_nacimiento
# Out:
#        0   1     2 fecha_nacimiento
# 0     25  03  2019       25-03-2019
# 1     25  03  2019       25-03-2019
# 2     25  03  2019       25-03-2019
# 3     02  10  2018       02-10-2018
# 4     17  09  2018       17-09-2018
# ...   ..  ..   ...              ...
# 1897  03  05  2019       03-05-2019
# 1898  03  05  2019       03-05-2019
# 1899  15  08  2018       15-08-2018
# 1900  23  10  2018       23-10-2018
# 1901  15  03  2019       15-03-2019
#
# [1901 rows x 4 columns]

# %%
df_nan = fechas_nacimiento[fechas_nacimiento.isna().any(axis=1)]
df_nan
# Out:
#         0     1     2 fecha_nacimiento
# 49   None  None  None   None-None-None
# 52   None  None  None   None-None-None
# 53   None  None  None   None-None-None
# 267   NaN   NaN   NaN      nan-nan-nan
# 539   NaN   NaN   NaN      nan-nan-nan
# 540   NaN   NaN   NaN      nan-nan-nan

# %%
fechas_nacimiento["fecha_nacimiento"] = pd.to_datetime( fechas_nacimiento["fecha_nacimiento"],errors='coerce' )
merged_df["date"] = pd.to_datetime(merged_df["date"], errors='coerce')
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_16644\959328220.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   fechas_nacimiento["fecha_nacimiento"] = pd.to_datetime( fechas_nacimiento["fecha_nacimiento"],errors='coerce' )

# %%
fechas_nacimiento[ pd.isna(fechas_nacimiento["fecha_nacimiento"]) ].shape
# Out:
# (9, 4)

# %%
merged_df.shape
# Out:
# (1901, 17)

# %%
df = merged_df.merge(fechas_nacimiento["fecha_nacimiento"], left_index=True, right_index=True)
df.shape
# Out:
# (1901, 18)

# %%
df["fecha_evaluacion"] = pd.to_datetime( df.date )

# %%
df["edad"] = ( (df["fecha_evaluacion"] - df["fecha_nacimiento"]) / np.timedelta64(1, 'D') ) / 30

# %%
df = df.drop( columns=["fecha_nac", "date"] )

# %% [markdown]
# #### Hay edades que están mal

# %%
df.edad.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.query("edad > 90").shape
# Out:
# (0, 18)

# %%
df.loc[ df.query("edad <= 40").index, "edad" ] = np.NaN

# %%
df.edad.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ##### Gente sin edad (%):

# %%
df.query("edad != edad").shape[0] / df.query("edad == edad").shape[0]
# Out:
# 0.02867965367965368

# %% [markdown]
# ## Agrego columna NODO

# %%
# Cargar el archivo Excel que contiene la asignación de nodos
df_nodos = pd.read_excel("localidad_df.xlsx")  # Reemplaza con la ruta de tu archivo

# Asegurar que ambas columnas "jardin" sean del mismo tipo
df["localidad"] = df["localidad"].astype(str)
df_nodos["localidad"] = df_nodos["localidad"].astype(str)

# Unir los DataFrames usando "localidad" como clave
df = df.merge(df_nodos, on="localidad", how="left")
df
# Out:
#                    test_name_x version  test_id_x  accuracy  accuracy_totales  \
# 0                      esp2022       A  1685-0002  0.882353          0.882353
# 1     concienciaFonologica2024       B  1685-0003  0.400000          0.400000
# 2         sistemaEscritura2024       A  1685-0004  0.400000          0.400000
# 3                      esp2022       A  2254-0001  0.529412          0.529412
# 4                      esp2022       B  2254-0002  0.941176          0.941176
# ...                        ...     ...        ...       ...               ...
# 1896                   esp2022       B  8447-0072  0.941176          0.941176
# 1897      sistemaEscritura2024       B  8447-0073  0.900000          0.900000
# 1898                   esp2022       B  8447-0075  0.533333          0.235294
# 1899                   esp2022       B  8447-0076  0.794118          0.794118
# 1900                   esp2022       B  8447-0077  0.794118          0.794118
#
#       attempts      latency     codigo     genero             jardin  \
# 0           34  2004.766667  ER2413711  Masculino  Esc Edu Prim N 35
# 1           20  2858.750000  ER2413711  Masculino  Esc Edu Prim N 35
# 2           10  2208.750000  ER2413711  Masculino  Esc Edu Prim N 35
# 3           34  4750.833333  ER2413401  Masculino          Ueni N 57
# 4           34  3184.406250  ER2413402   Femenino          Ueni N 57
# ...        ...          ...        ...        ...                ...
# 1896        34  2574.562500  ER2411104   Femenino  Esc Edu Prim N 36
# 1897        10  1352.000000  ER2411104   Femenino  Esc Edu Prim N 36
# 1898        15  3769.750000  ER2412203   Femenino  Esc Edu Prim N 23
# 1899        34  2973.222222  ER2412202   Femenino  Esc Edu Prim N 23
# 1900        34  3413.962963  ER2412201   Femenino  Esc Edu Prim N 23
#
#            sala                                supervision  localidad  \
# 0     MULTIEDAD             Tala Zona Xvii - Mónica Londra    Durazno
# 1     MULTIEDAD             Tala Zona Xvii - Mónica Londra    Durazno
# 2     MULTIEDAD             Tala Zona Xvii - Mónica Londra    Durazno
# 3        verde    Diamante Zona Xii - Miriam Elena Retegui   Diamante
# 4         verde   Diamante Zona Xii - Miriam Elena Retegui   Diamante
# ...         ...                                        ...        ...
# 1896          5  Concordia Zona V - Cecilia Julieta Garcia  Concordia
# 1897          5  Concordia Zona V - Cecilia Julieta Garcia  Concordia
# 1898     5 años       Parana  Zona Ii - Claudio G. Lomagno     Paraná
# 1899     5 años       Parana  Zona Ii - Claudio G. Lomagno     Paraná
# 1900     5 años       Parana  Zona Ii - Claudio G. Lomagno     Paraná
#
#       ocup_padres                                        comentarios  \
# 0        EMPLEADO                                                NaN
# 1        EMPLEADO                                                NaN
# 2        EMPLEADO                                                NaN
# 3     Ama de casa  Es un niño con TE, asiste al jardín con su aco...
# 4         Policia                                                NaN
# ...           ...                                                ...
# 1896  ama de casa                                  PRIMARIO COMPLETO
# 1897  ama de casa                                  PRIMARIO COMPLETO
# 1898          NaN                                                NaN
# 1899          NaN                                                NaN
# 1900          NaN                                                NaN
#
#      fecha_nacimiento fecha_evaluacion       edad  Nodo
# 0          2019-03-25       2024-12-04  69.366667     4
# 1          2019-03-25       2024-12-04  69.366667     4
# 2          2019-03-25       2024-12-04  69.366667     4
# 3          2018-02-10       2024-11-14  82.300000     3
# 4          2018-09-17       2024-11-14  75.000000     3
# ...               ...              ...        ...   ...
# 1896       2019-03-05       2024-12-04  70.033333     2
# 1897       2019-03-05       2024-12-04  70.033333     2
# 1898       2018-08-15       2024-12-17  77.200000     3
# 1899       2018-10-23       2024-12-17  74.900000     3
# 1900       2019-03-15       2024-12-17  70.133333     3
#
# [1901 rows x 19 columns]

# %%
# Diccionario de mapeo
diccionario = {
    "1": "Federal",
    "2": "Concordia",
    "3": "Paraná",
    "4": "Gualeguaychú"
}

# Asegurarse de que la columna 'nodo' sea de tipo cadena y realizar la sustitución
df["Nodo"] = df["Nodo"].astype(str).map(diccionario).fillna(df["Nodo"])
df
# Out:
#                    test_name_x version  test_id_x  accuracy  accuracy_totales  \
# 0                      esp2022       A  1685-0002  0.882353          0.882353
# 1     concienciaFonologica2024       B  1685-0003  0.400000          0.400000
# 2         sistemaEscritura2024       A  1685-0004  0.400000          0.400000
# 3                      esp2022       A  2254-0001  0.529412          0.529412
# 4                      esp2022       B  2254-0002  0.941176          0.941176
# ...                        ...     ...        ...       ...               ...
# 1896                   esp2022       B  8447-0072  0.941176          0.941176
# 1897      sistemaEscritura2024       B  8447-0073  0.900000          0.900000
# 1898                   esp2022       B  8447-0075  0.533333          0.235294
# 1899                   esp2022       B  8447-0076  0.794118          0.794118
# 1900                   esp2022       B  8447-0077  0.794118          0.794118
#
#       attempts      latency     codigo     genero             jardin  \
# 0           34  2004.766667  ER2413711  Masculino  Esc Edu Prim N 35
# 1           20  2858.750000  ER2413711  Masculino  Esc Edu Prim N 35
# 2           10  2208.750000  ER2413711  Masculino  Esc Edu Prim N 35
# 3           34  4750.833333  ER2413401  Masculino          Ueni N 57
# 4           34  3184.406250  ER2413402   Femenino          Ueni N 57
# ...        ...          ...        ...        ...                ...
# 1896        34  2574.562500  ER2411104   Femenino  Esc Edu Prim N 36
# 1897        10  1352.000000  ER2411104   Femenino  Esc Edu Prim N 36
# 1898        15  3769.750000  ER2412203   Femenino  Esc Edu Prim N 23
# 1899        34  2973.222222  ER2412202   Femenino  Esc Edu Prim N 23
# 1900        34  3413.962963  ER2412201   Femenino  Esc Edu Prim N 23
#
#            sala                                supervision  localidad  \
# 0     MULTIEDAD             Tala Zona Xvii - Mónica Londra    Durazno
# 1     MULTIEDAD             Tala Zona Xvii - Mónica Londra    Durazno
# 2     MULTIEDAD             Tala Zona Xvii - Mónica Londra    Durazno
# 3        verde    Diamante Zona Xii - Miriam Elena Retegui   Diamante
# 4         verde   Diamante Zona Xii - Miriam Elena Retegui   Diamante
# ...         ...                                        ...        ...
# 1896          5  Concordia Zona V - Cecilia Julieta Garcia  Concordia
# 1897          5  Concordia Zona V - Cecilia Julieta Garcia  Concordia
# 1898     5 años       Parana  Zona Ii - Claudio G. Lomagno     Paraná
# 1899     5 años       Parana  Zona Ii - Claudio G. Lomagno     Paraná
# 1900     5 años       Parana  Zona Ii - Claudio G. Lomagno     Paraná
#
#       ocup_padres                                        comentarios  \
# 0        EMPLEADO                                                NaN
# 1        EMPLEADO                                                NaN
# 2        EMPLEADO                                                NaN
# 3     Ama de casa  Es un niño con TE, asiste al jardín con su aco...
# 4         Policia                                                NaN
# ...           ...                                                ...
# 1896  ama de casa                                  PRIMARIO COMPLETO
# 1897  ama de casa                                  PRIMARIO COMPLETO
# 1898          NaN                                                NaN
# 1899          NaN                                                NaN
# 1900          NaN                                                NaN
#
#      fecha_nacimiento fecha_evaluacion       edad          Nodo
# 0          2019-03-25       2024-12-04  69.366667  Gualeguaychú
# 1          2019-03-25       2024-12-04  69.366667  Gualeguaychú
# 2          2019-03-25       2024-12-04  69.366667  Gualeguaychú
# 3          2018-02-10       2024-11-14  82.300000        Paraná
# 4          2018-09-17       2024-11-14  75.000000        Paraná
# ...               ...              ...        ...           ...
# 1896       2019-03-05       2024-12-04  70.033333     Concordia
# 1897       2019-03-05       2024-12-04  70.033333     Concordia
# 1898       2018-08-15       2024-12-17  77.200000        Paraná
# 1899       2018-10-23       2024-12-17  74.900000        Paraná
# 1900       2019-03-15       2024-12-17  70.133333        Paraná
#
# [1901 rows x 19 columns]

# %% [markdown]
# ## Grabo

# %%
df.to_csv("df-por_chico-clean_entrerios.csv", index=None)
